# %%
from torch.utils.data import Dataset
from torchvision import transforms
from PIL import Image
from imutils import paths
from typing import Tuple
import numpy as np
import os

imagePaths = paths.list_images("/Users/elizabethmoore/PPs/habs_github/data/imported_images/test_images")
print(imagePaths)
# Out:
# <generator object list_files at 0x7f8e382357d0>

# %%
from torch.utils.data import Dataset
from torchvision import transforms
from PIL import Image
from imutils import paths
from typing import Tuple
import numpy as np
import os
from pathlib import Path

p = Path('/Users/elizabethmoore/PPs/habs/ExtractedPics').glob('**/*')
print(p)
# file_paths = [x for x in p if 
#               (x.parents[-1] == 'bga' or 
#                x.parents[-1] == 'clear' or
#                x.parents[-1] == 'turbid')]
# print(file_paths)
print(len(file_paths))
for file_path in file_paths:
#     print(file_path)
    print(file_path.parent.name)
# Out:
# <generator object Path.glob at 0x7f8e383d00d0>
# 274
# ExtractedPics
# ExtractedPics
# ExtractedPics
# ExtractedPics
# bga
# bga
# bga
# bga
# bga
# bga
# bga
# bga
# bga
# bga
# bga
# bga
# bga
# bga
# bga
# bga
# bga
# bga
# bga
# bga
# bga
# bga
# bga
# bga
# bga
# bga
# clear
# clear
# clear
# clear
# clear
# clear
# clear
# clear
# clear
# clear
# clear
# clear
# clear
# clear
# clear
# clear
# clear
# clear
# clear
# clear
# clear
# clear
# clear
# clear
# clear
# clear
# clear
# clear
# clear
# clear
# clear
# clear
# clear
# clear
# clear
# clear
# clear
# clear
# clear
# clear
# clear
# clear
# clear
# clear
# clear
# clear
# clear
# clear
# clear
# clear
# clear
# clear
# clear
# clear
# clear
# clear
# clear
# clear
# clear
# clear
# clear
# clear
# clear
# clear
# clear
# clear
# clear
# clear
# clear
# clear
# clear
# clear
# clear
# clear
# clear
# clear
# clear
# clear
# clear
# clear
# clear
# clear
# clear
# clear
# clear
# clear
# clear
# clear
# clear
# clear
# ...

# %%
from pathlib import Path

all_paths = Path('/Users/elizabethmoore/PPs/habs/ExtractedPics').glob('**/*')
print(p)

# for file_path in all_paths:
# #     print(file_path)
#     print(file_path.parent.name)
    
image_paths = [file_path for file_path in all_paths if 
               (file_path.name != '.DS_Store') and
              (file_path.parent.name == 'bga' or 
               file_path.parent.name == 'clear' or
               file_path.parent.name == 'turbid')]
# print(image_paths)
print(len(image_paths))

for image_path in image_paths:
    print(image_path)
#     print(image_path.name)
# Out:
# <generator object Path.glob at 0x7f8e35459a50>
# 267
# /Users/elizabethmoore/PPs/habs/ExtractedPics/bga/MP 10-08-19 x00075.jpg
# /Users/elizabethmoore/PPs/habs/ExtractedPics/bga/MP 10-08-19 x00077.jpg
# /Users/elizabethmoore/PPs/habs/ExtractedPics/bga/MP 10-08-19 x00073.jpg
# /Users/elizabethmoore/PPs/habs/ExtractedPics/bga/MP 10-08-19 x00071.jpg
# /Users/elizabethmoore/PPs/habs/ExtractedPics/bga/bgaclear00107.jpg
# /Users/elizabethmoore/PPs/habs/ExtractedPics/bga/MP 07-31-1900079.jpg
# /Users/elizabethmoore/PPs/habs/ExtractedPics/bga/MP 07-31-1900085.jpg
# /Users/elizabethmoore/PPs/habs/ExtractedPics/bga/bgaclear00111.jpg
# /Users/elizabethmoore/PPs/habs/ExtractedPics/bga/bgaclear00105.jpg
# /Users/elizabethmoore/PPs/habs/ExtractedPics/bga/MP 08-02-19 x00079.jpg
# /Users/elizabethmoore/PPs/habs/ExtractedPics/bga/bgaclear00115.jpg
# /Users/elizabethmoore/PPs/habs/ExtractedPics/bga/MP 08-02-19 x00087.jpg
# /Users/elizabethmoore/PPs/habs/ExtractedPics/bga/MP 08-02-19 x00091.jpg
# ...

# %%
from pathlib import Path

all_paths = Path('/Users/elizabethmoore/PPs/habs/ExtractedPics').glob('**/*')
    
image_paths = [file_path for file_path in all_paths if 
               (file_path.name != '.DS_Store') and
              (file_path.parent.name == 'bga' or 
               file_path.parent.name == 'clear' or
               file_path.parent.name == 'turbid')]

print(image_paths)
print(len(image_paths))

for image_path in image_paths:
    print(image_path)
# Out:
# [PosixPath('/Users/elizabethmoore/PPs/habs/ExtractedPics/bga/MP 10-08-19 x00075.jpg'), PosixPath('/Users/elizabethmoore/PPs/habs/ExtractedPics/bga/MP 10-08-19 x00077.jpg'), PosixPath('/Users/elizabethmoore/PPs/habs/ExtractedPics/bga/MP 10-08-19 x00073.jpg'), PosixPath('/Users/elizabethmoore/PPs/habs/ExtractedPics/bga/MP 10-08-19 x00071.jpg'), PosixPath('/Users/elizabethmoore/PPs/habs/ExtractedPics/bga/bgaclear00107.jpg'), PosixPath('/Users/elizabethmoore/PPs/habs/ExtractedPics/bga/MP 07-31-1900079.jpg'), PosixPath('/Users/elizabethmoore/PPs/habs/ExtractedPics/bga/MP 07-31-1900085.jpg'), PosixPath('/Users/elizabethmoore/PPs/habs/ExtractedPics/bga/bgaclear00111.jpg'), PosixPath('/Users/elizabethmoore/PPs/habs/ExtractedPics/bga/bgaclear00105.jpg'), PosixPath('/Users/elizabethmoore/PPs/habs/ExtractedPics/bga/MP 08-02-19 x00079.jpg'), PosixPath('/Users/elizabethmoore/PPs/habs/ExtractedPics/bga/bgaclear00115.jpg'), PosixPath('/Users/elizabethmoore/PPs/habs/ExtractedPics/bga/MP 08-02-19 x00
# ...

# %%
from pathlib import Path

all_paths = Path('/Users/elizabethmoore/PPs/habs/ExtractedPics').glob("**/*")
    
image_paths = [file_path for file_path in all_paths if 
               (file_path.name != '.DS_Store') and
              (file_path.parent.name == 'bga' or 
               file_path.parent.name == 'clear' or
               file_path.parent.name == 'turbid')]

# print(image_paths)
# print(len(image_paths))

# for image_path in image_paths:
#     print(image_path)
    
im_path = image_paths[9]
_class = im_path.parent.name
if _class == "bga":
    target = 0
elif _class == "clear":
    target = 1
elif _class == "turbid":
    target = 2

print(im_path.name)
print(im_path)
print(im_path.parent)
print(im_path.parent.name)
print(target)
# Out:
# MP 08-02-19 x00079.jpg
# /Users/elizabethmoore/PPs/habs/ExtractedPics/bga/MP 08-02-19 x00079.jpg
# /Users/elizabethmoore/PPs/habs/ExtractedPics/bga
# bga
# 0

# %%
from pathlib import Path

all_paths = Path('/Users/elizabethmoore/PPs/habs/ExtractedPics').glob("**/*")
    
image_paths = [file_path for file_path in all_paths if 
               (file_path.suffix == ".jpg")]

print(len(image_paths))
# print(image_paths)

for image_path in image_paths:
    print(image_path)
    
# im_path = image_paths[9]
# print(im_path.suffix)
# Out:
# 267
# /Users/elizabethmoore/PPs/habs/ExtractedPics/bga/MP 10-08-19 x00075.jpg
# /Users/elizabethmoore/PPs/habs/ExtractedPics/bga/MP 10-08-19 x00077.jpg
# /Users/elizabethmoore/PPs/habs/ExtractedPics/bga/MP 10-08-19 x00073.jpg
# /Users/elizabethmoore/PPs/habs/ExtractedPics/bga/MP 10-08-19 x00071.jpg
# /Users/elizabethmoore/PPs/habs/ExtractedPics/bga/bgaclear00107.jpg
# /Users/elizabethmoore/PPs/habs/ExtractedPics/bga/MP 07-31-1900079.jpg
# /Users/elizabethmoore/PPs/habs/ExtractedPics/bga/MP 07-31-1900085.jpg
# /Users/elizabethmoore/PPs/habs/ExtractedPics/bga/bgaclear00111.jpg
# /Users/elizabethmoore/PPs/habs/ExtractedPics/bga/bgaclear00105.jpg
# /Users/elizabethmoore/PPs/habs/ExtractedPics/bga/MP 08-02-19 x00079.jpg
# /Users/elizabethmoore/PPs/habs/ExtractedPics/bga/bgaclear00115.jpg
# /Users/elizabethmoore/PPs/habs/ExtractedPics/bga/MP 08-02-19 x00087.jpg
# /Users/elizabethmoore/PPs/habs/ExtractedPics/bga/MP 08-02-19 x00091.jpg
# ...

# %%
x = 'hiy'

if x in {'hi', 'bye'}:
    print(True)
else:
    print(False)
# Out:
# False

# %%
from pathlib import Path

all_paths = Path('/Users/elizabethmoore/PPs/habs/ExtractedPics').glob('**/*')
    
image_paths = [fp for fp in all_paths if fp.suffix == ".jpg" and fp.parent.name in {"bga", "clear", "turbid"}]

print(image_paths)
print(len(image_paths))

for image_path in image_paths:
    print(type(image_path))
# Out:
# [PosixPath('/Users/elizabethmoore/PPs/habs/ExtractedPics/bga/MP 10-08-19 x00075.jpg'), PosixPath('/Users/elizabethmoore/PPs/habs/ExtractedPics/bga/MP 10-08-19 x00077.jpg'), PosixPath('/Users/elizabethmoore/PPs/habs/ExtractedPics/bga/MP 10-08-19 x00073.jpg'), PosixPath('/Users/elizabethmoore/PPs/habs/ExtractedPics/bga/MP 10-08-19 x00071.jpg'), PosixPath('/Users/elizabethmoore/PPs/habs/ExtractedPics/bga/bgaclear00107.jpg'), PosixPath('/Users/elizabethmoore/PPs/habs/ExtractedPics/bga/MP 07-31-1900079.jpg'), PosixPath('/Users/elizabethmoore/PPs/habs/ExtractedPics/bga/MP 07-31-1900085.jpg'), PosixPath('/Users/elizabethmoore/PPs/habs/ExtractedPics/bga/bgaclear00111.jpg'), PosixPath('/Users/elizabethmoore/PPs/habs/ExtractedPics/bga/bgaclear00105.jpg'), PosixPath('/Users/elizabethmoore/PPs/habs/ExtractedPics/bga/MP 08-02-19 x00079.jpg'), PosixPath('/Users/elizabethmoore/PPs/habs/ExtractedPics/bga/bgaclear00115.jpg'), PosixPath('/Users/elizabethmoore/PPs/habs/ExtractedPics/bga/MP 08-02-19 x00
# ...

# %%
mode = "sup"
print("Dataset mode must be either train, test, or classify. Value entered: {}".format(mode))
# Out:
# Dataset mode must be either train, test, or classify. Value entered: sup
